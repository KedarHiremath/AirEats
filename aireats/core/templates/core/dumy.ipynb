# %%
{% extends 'core/base.html' %}

{% block title %}Login - AirEats{% endblock %}

{% block content %}
<h2>Login</h2>

{% if error %}
<p style="color:red;">{{ error }}</p>
{% endif %}

<form method="post" action="{% url 'login_page' %}">
    {% csrf_token %}
    <input type="text" name="identifier" placeholder="Username / Email / Phone" required><br>
    <input type="password" name="password" placeholder="Password" required><br>
    <button type="submit">Login</button>
</form>

<p>Don't have an account? <a href="{% url 'signup_page' %}">Signup</a></p>
{% endblock %}

# %%
<!-- {% extends 'core/base.html' %}

{% block title %}Signup - AirEats{% endblock %}

{% block content %}
<h2>Signup</h2>

{% if error %}
<p style="color:red;">{{ error }}</p>
{% endif %}

<form method="post" action="{% url 'signup_page' %}">
    {% csrf_token %}
    <input type="text" name="username" placeholder="Username" required><br>
    <input type="password" name="password" placeholder="Password" required><br>
    <input type="password" name="confirm_password" placeholder="Confirm Password" required><br>
    <input type="text" name="first_name" placeholder="First Name" required><br>
    <input type="text" name="last_name" placeholder="Last Name" required><br>
    <input type="email" name="email" placeholder="Email" required><br>
    <input type="text" name="phone" placeholder="Phone" required><br>

    <select name="sex">
        <option value="">Sex (Optional)</option>
        <option value="Male">Male</option>
        <option value="Female">Female</option>
        <option value="Other">Other</option>
    </select><br>

    <input type="date" name="dob" placeholder="Date of Birth"><br>
    <input type="text" name="nationality" placeholder="Nationality"><br>
    <input type="text" name="address" placeholder="Address"><br>

    <button type="submit">Signup</button>
</form>

<p>Already have an account? <a href="{% url 'login_page' %}">Login</a></p>
{% endblock %} -->

# %%
<!-- {% extends 'core/base.html' %}
{% load static %}

{% block title %}Home - AirEats{% endblock %}

{% block content %}
<h1>Welcome to AirEats</h1>
<p>Your favorite meals delivered fast!</p> -->

<!-- Example logo reuse -->
<!-- <img src="{% static 'core/images/logo.png' %}" alt="AirEats Logo" height="120">

<div>
    <a href="{% url 'login_page' %}">Login</a> |
    <a href="{% url 'signup_page' %}">Signup</a>
</div>
{% endblock %} -->

# %%
@keyframes slideShow {
    0%, 20% { transform: translateX(0%); }
    25%, 45% { transform: translateX(-100%); }
    50%, 70% { transform: translateX(-200%); }
    75%, 95% { transform: translateX(-300%); }
    100% { transform: translateX(0%); }
}

# %%
{% extends 'core/base.html' %}
{% load static %}

{% block title %}Home - AirEats{% endblock %}

{% block content %}
<div class="hero">
    <!-- Left text -->
    <div class="hero-text">
        <h1>Hungry? Just AirEats.</h1>
        <p>Because airplane mode doesn’t apply to hunger.</p>
        <a href="{% url 'login_page' %}" class="btn">Login</a>
        <a href="{% url 'signup_page' %}" class="btn">Signup</a>
    </div>

    <!-- Right image slider -->
    <div class="hero-slider">
        <div class="slides">
            <div class="slide"><img src="{% static 'core/images/food1.png' %}" alt="Food 1"></div>
            <div class="slide"><img src="{% static 'core/images/food2.png' %}" alt="Food 2"></div>
            <div class="slide"><img src="{% static 'core/images/food3.png' %}" alt="Food 3"></div>
            <div class="slide"><img src="{% static 'core/images/food4.png' %}" alt="Food 4"></div>
        </div>
    </div>
</div>
{% endblock %}

# %%
/* Background - clean but quirky */
body {
    margin: 0;
    font-family: 'Poppins', sans-serif;
    background: linear-gradient(135deg, #fffaf5 0%, #fdfdfd 50%, #fff3e0 100%);
    overflow-x: hidden;
}

/* Add quirky floating shapes in background */
body::before, body::after {
    content: "";
    position: absolute;
    width: 200px;
    height: 200px;
    background: rgba(255, 200, 150, 0.15);
    border-radius: 50%;
    z-index: -1;
    animation: float 12s ease-in-out infinite;
}
body::before {
    top: 10%;
    left: -5%;
}
body::after {
    bottom: 10%;
    right: -5%;
}

@keyframes float {
    0%, 100% { transform: translateY(0px); }
    50% { transform: translateY(40px); }
}

/* Layout split screen */
.hero {
    display: flex;
    height: 100vh;
    align-items: center;
    justify-content: space-between;
    padding: 0 80px;
}

/* Left text section */
.hero-text {
    flex: 1;
    color: #333;
}
.hero-text h1 {
    font-size: 3.5rem;
    font-weight: 700;
    color: #ff7043;
}
.hero-text p {
    font-size: 1.3rem;
    margin: 15px 0 25px;
    color: #444;
    font-style: italic;
}
.hero-text .btn {
    padding: 12px 28px;
    margin-right: 15px;
    background: #ff7043;
    color: white;
    font-weight: bold;
    border-radius: 30px;
    text-decoration: none;
    transition: background 0.3s ease;
}
.hero-text .btn:hover {
    background: #ff5722;
}

/* Right image slider */
.hero-slider {
    flex: 1;
    height:1000px;
    position: relative;
    overflow: hidden;
    border-radius: 20px;
    background: #fff7f0;
}
.slides {
    display: flex;
    width: 400%;
    height: 100%;
    animation: slideShow 40s infinite;
}
.slide {
    width: 100%;
    flex-shrink: 0;
}
.slide img {
    width: 100%;
    height: 100%;
    object-fit: contain; /* show full image */
    object-position: center;
    background: #fff7f0; /* soft background behind transparent images */
    padding: 20px; /* optional breathing space */
}


/* Keyframes for smooth seamless sliding */
@keyframes slideShow {
    /* 1st image visible */
    0%, 25%   { transform: translateX(0%); }

    /* 2nd image visible */
    30%, 55%  { transform: translateX(-100%); }

    /* 3rd image visible */
    60%, 85%  { transform: translateX(-200%); }

    /* 4th image visible */
    90%, 100% { transform: translateX(-300%); }
}

# %% [markdown]
# latest home.html-problematic

# %%
{% extends 'core/base.html' %}
{% load static %}

{% block title %}Home - AirEats{% endblock %}

{% block content %}
<div class="ae-home-full">

  <!-- Background carousel -->
  <div class="ae-carousel">
    <div class="ae-track">
      <div class="ae-item"><img src="{% static 'core/images/food1.png' %}" alt="Food 1"></div>
      <div class="ae-item"><img src="{% static 'core/images/food2.png' %}" alt="Food 2"></div>
      <div class="ae-item"><img src="{% static 'core/images/food3.png' %}" alt="Food 3"></div>
    </div>
  </div>

  <!-- Foreground center strip -->
  <div class="ae-strip">
    <h1 class="ae-heading">Hungry? Just <span class="ae-highlight">AirEats</span>.</h1>
    <p class="ae-sub">Because airplane mode doesn’t apply to hunger.</p>
    <div class="ae-ctas">
      <a href="{% url 'login_page' %}" class="ae-btn">Login</a>
      <a href="{% url 'signup_page' %}" class="ae-btn ae-btn-outline">Signup</a>
    </div>
  </div>

</div>
{% endblock %}

# %% [markdown]
# initial codes

# %% [markdown]
# {% load static %}
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>{% block title %}AirEats{% endblock %}</title>
#     <link rel="stylesheet" href="{% static 'core/style.css' %}">
# </head>
# <body>
#     <!-- Header with Logo -->
#     <header>
#         <img src="{% static 'core/images/logo.png' %}" alt="AirEats Logo" height="60">
#         <nav>
#             <a href="{% url 'home' %}">Home</a>
#             <a href="{% url 'login_page' %}">Login</a>
#             <a href="{% url 'signup_page' %}">Signup</a>
#         </nav>
#     </header>
#
#     <!-- Page content -->
#     <main>
#         {% block content %}{% endblock %}
#     </main>
# </body>
# </html>

# %% [markdown]
# {% extends 'core/base.html' %}
# {% block title %}Booking - AirEats{% endblock %}
# {% block content %}
#
# <h2>Welcome, {{ username }}</h2>
#
# <!-- Quick navigation buttons -->
# <div style="margin-bottom: 20px;">
#     <a href="{% url 'orders_page' username=username %}">
#         <button type="button">Confirmed Orders</button>
#     </a>
#     <a href="{% url 'order_history_page' username=username %}">
#         <button type="button">Order History</button>
#     </a>
# </div>
#
# {% if error %}<p style="color:red;">{{ error }}</p>{% endif %}
# {% if msg %}<p style="color:green;">{{ msg }}</p>{% endif %}
#
# <h3>Restaurants</h3>
# <ul>
#   {% for r in restaurants %}
#     <li>
#       <a href="{% url 'restaurant_page' username=username restaurant_id=r.restaurant_id %}">
#         {{ r.restaurant_name }}
#       </a>
#     </li>
#   {% endfor %}
# </ul>
#
# <hr>
# <h3>Your Cart</h3>
# {% if cart %}
#   <ul>
#     {% for oi in cart %}
#       <li>
#         {{ oi.dish_name }} — ₹{{ oi.dish_price }} × {{ oi.quantity }}
#         <form method="post" style="display:inline;">
#           {% csrf_token %}
#           <input type="hidden" name="action" value="add">
#           <input type="hidden" name="dish_id" value="{{ oi.dish_id }}">
#           <button type="submit">+</button>
#         </form>
#         <form method="post" style="display:inline;">
#           {% csrf_token %}
#           <input type="hidden" name="action" value="remove">
#           <input type="hidden" name="dish_id" value="{{ oi.dish_id }}">
#           <button type="submit">−</button>
#         </form>
#       </li>
#     {% endfor %}
#   </ul>
#   <p><strong>Total: ₹{{ total }}</strong></p>
#
#   <!-- If boarding pass not yet stored, show fetch form -->
#   {% if not booking.boarding_pass_number %}
#     <form method="post">
#       {% csrf_token %}
#       <input type="hidden" name="action" value="fetch_details">
#       <label>Boarding Pass Number:</label>
#       <input type="text" name="boarding_pass_number" required>
#       <button type="submit">Fetch Details</button>
#     </form>
#   {% else %}
#     <!-- Display fetched details -->
#     <h4>Boarding Details</h4>
#     <p><strong>Boarding Pass:</strong> {{ booking.boarding_pass_number }}</p>
#     <p><strong>Location:</strong> {{ booking.location }}</p>
#
#     <!-- Reset boarding pass -->
#     <form method="post" style="display:inline;">
#       {% csrf_token %}
#       <input type="hidden" name="action" value="reset_boarding">
#       <button type="submit">Reset Boarding Pass</button>
#     </form>
#
#     <!-- Place order button (next step) -->
#     <form action="{% url 'payment_page' username=username booking_id=booking.booking_id %}" method="get" style="display:inline; margin-left:10px;">
#       <button type="submit">Confirm Order</button>
#     </form>
#
#   {% endif %}
#
# {% else %}
#   <p>Your cart is empty.</p>
# {% endif %}
#
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% load static %}
#
# {% block title %}Home - AirEats{% endblock %}
#
# {% block content %}
# <div class="ae-home-full">
#
#   <!-- Background carousel -->
#   <div class="ae-carousel">
#     <div class="ae-track">
#       <div class="ae-item"><img src="{% static 'core/images/food1.png' %}" alt="Food 1"></div>
#       <div class="ae-item"><img src="{% static 'core/images/food2.png' %}" alt="Food 2"></div>
#       <div class="ae-item"><img src="{% static 'core/images/food3.png' %}" alt="Food 3"></div>
#     </div>
#   </div>
#
#   <!-- Foreground center strip -->
#   <div class="ae-strip">
#     <h1 class="ae-heading">Hungry? Just <span class="ae-highlight">AirEats</span>.</h1>
#     <p class="ae-sub">Because airplane mode doesn’t apply to hunger.</p>
#     <div class="ae-ctas">
#       <a href="{% url 'login_page' %}" class="ae-btn">Login</a>
#       <a href="{% url 'signup_page' %}" class="ae-btn ae-btn-outline">Signup</a>
#     </div>
#   </div>
#
# </div>
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% load static %}
#
#
# {% block title %}Login - AirEats{% endblock %}
#
# {% block content %}
# <div class="login-container">
#     <div class="login-card">
#         <div class="logo">
#             <img src="{% static 'core/images/logo.png' %}" alt="AirEats Logo">
#         </div>
#         <h2 class="login-title">Welcome Back</h2>
#         <p class="login-subtitle">Login to continue your journey with AirEats</p>
#
#         {% if error %}
#         <p class="error-message">{{ error }}</p>
#         {% endif %}
#
#         <form method="post" action="{% url 'login_page' %}">
#             {% csrf_token %}
#             <div class="input-group">
#                 <input type="text" name="identifier" placeholder="Username / Email / Phone" required>
#             </div>
#             <div class="input-group">
#                 <input type="password" name="password" placeholder="Password" required>
#             </div>
#             <button type="submit" class="login-btn">Login</button>
#         </form>
#
#         <p class="signup-text">
#             Don’t have an account? <a href="{% url 'signup_page' %}">Sign up</a>
#         </p>
#     </div>
# </div>
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% block title %}Order History - AirEats{% endblock %}
# {% block content %}
#
# <h2>Order History for {{ username }}</h2>
#
# {% if orders %}
#   <ul>
#     {% for order in orders %}
#       <li>
#         <h4>Booking ID: {{ order.booking_id }}</h4>
#         <p>Status: {{ order.status }}</p>
#         <p>Location: {{ order.location }}</p>
#         <p>Total: ₹{{ order.amount }}</p>
#
#         <h5>Items:</h5>
#         <ul>
#           {% for oi in order.order %}
#             <li>{{ oi.dish_name }} — ₹{{ oi.dish_price }} × {{ oi.quantity }}</li>
#           {% endfor %}
#         </ul>
#       </li>
#       <hr>
#     {% endfor %}
#   </ul>
# {% else %}
#   <p>No completed orders yet.</p>
# {% endif %}
#
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% load custom_filters %}
# {% block title %}My Orders - AirEats{% endblock %}
# {% block content %}
#
# <h2>Confirmed Orders for {{ username }}</h2>
#
# {% if orders %}
#   <ul>
#     {% for order in orders %}
#       <li>
#         <h4>Booking ID: {{ order.booking_id }}</h4>
#         <p>Status: {{ order.status }}</p>
#         <p>Location: {{ order.location }}</p>
#         <p>Total: ₹{{ order.amount }}</p>
#
#         <h5>Items:</h5>
#         <ul>
#           {% for oi in order.order %}
#             <li>{{ oi.dish_name }} — ₹{{ oi.dish_price }} × {{ oi.quantity }}</li>
#           {% endfor %}
#         </ul>
#
#         {% with payments|get_item:order.booking_id as payment %}
#           {% if payment %}
#             <h5>Payment Details:</h5>
#             <p><strong>Transaction ID:</strong> {{ payment.transaction_id }}</p>
#             <p><strong>Method:</strong> {{ payment.payment_method }}</p>
#             <p><strong>Timestamp:</strong> {{ payment.timestamp }}</p>
#           {% else %}
#             <p style="color:red;">⚠ No payment record found!</p>
#           {% endif %}
#         {% endwith %}
#
#         <form method="post" style="margin-top:10px;">
#           {% csrf_token %}
#           <input type="hidden" name="booking_id" value="{{ order.booking_id }}">
#           <button type="submit">Received</button>
#         </form>
#       </li>
#       <hr>
#     {% endfor %}
#   </ul>
# {% else %}
#   <p>No confirmed orders yet.</p>
# {% endif %}
#
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% block title %}Payment - AirEats{% endblock %}
# {% block content %}
#
# <h2>Payment for Booking {{ booking.booking_id }}</h2>
# <p><strong>Total Amount:</strong> ₹{{ booking.amount }}</p>
#
# {% if error %}<p style="color:red;">{{ error }}</p>{% endif %}
#
# <form method="post">
#   {% csrf_token %}
#   <label>Select Payment Method:</label><br>
#   <input type="radio" name="payment_method" value="UPI"> UPI<br>
#   <input type="radio" name="payment_method" value="Card"> Card<br>
#   <input type="radio" name="payment_method" value="Net Banking"> Net Banking<br>
#   <input type="radio" name="payment_method" value="Cash"> Cash<br>
#   <br>
#   <button type="submit">Make Payment</button>
# </form>
#
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% block title %}Restaurant Menu{% endblock %}
# {% block content %}
#
# <h2>Restaurant Menu</h2>
#
# {% if error %}<p style="color:red;">{{ error }}</p>{% endif %}
#
# {% for item in dishes %}
#   <div>
#     <strong>{{ item.dish_name }}</strong> — ₹{{ item.price }}
#     <p>{{ item.description }}</p>
#
#     <form method="post" style="display:inline;">
#       {% csrf_token %}
#       <input type="hidden" name="action" value="add">
#       <input type="hidden" name="dish_id" value="{{ item.dish_id }}">
#       <button type="submit">+</button>
#     </form>
#     <form method="post" style="display:inline;">
#       {% csrf_token %}
#       <input type="hidden" name="action" value="remove">
#       <input type="hidden" name="dish_id" value="{{ item.dish_id }}">
#       <button type="submit">−</button>
#     </form>
#
#     <!-- ✅ Correct quantity display -->
#     {% with 0 as qty %}
#       {% for oi in cart %}
#         {% if oi.dish_id == item.dish_id %}
#           <span>Quantity: {{ oi.quantity }}</span>
#         {% endif %}
#       {% endfor %}
#     {% endwith %}
#   </div>
#   <hr>
# {% endfor %}
#
# <p><a href="{% url 'booking_page' username=username %}">← Back to Booking</a></p>
#
# {% endblock %}

# %% [markdown]
# {% extends 'core/base.html' %}
# {% load static %}
#
# {% block title %}Signup - AirEats{% endblock %}
#
# {% block content %}
# <div class="signup-container">
#     <div class="signup-card">
#         <div class="logo">
#             <img src="{% static 'core/images/logo.png' %}" alt="AirEats Logo">
#         </div>
#         <h2 class="signup-title">Create Your Account</h2>
#         <p class="signup-subtitle">Join AirEats and make your travel meals seamless</p>
#
#         {% if error %}
#         <p class="error-message">{{ error }}</p>
#         {% endif %}
#
#         <form method="post" action="{% url 'signup_page' %}">
#             {% csrf_token %}
#
#             <div class="input-group">
#                 <input type="text" name="username" placeholder="Username" required>
#             </div>
#
#             <div class="input-group">
#                 <input type="password" name="password" placeholder="Password" required>
#             </div>
#
#             <div class="input-group">
#                 <input type="password" name="confirm_password" placeholder="Confirm Password" required>
#             </div>
#
#             <div class="input-group">
#                 <input type="text" name="first_name" placeholder="First Name" required>
#             </div>
#
#             <div class="input-group">
#                 <input type="text" name="last_name" placeholder="Last Name" required>
#             </div>
#
#             <div class="input-group">
#                 <input type="email" name="email" placeholder="Email" required>
#             </div>
#
#             <div class="input-group">
#                 <input type="text" name="phone" placeholder="Phone" required>
#             </div>
#
#             <div class="input-group">
#                 <select name="sex">
#                     <option value="">Sex (Optional)</option>
#                     <option value="Male">Male</option>
#                     <option value="Female">Female</option>
#                     <option value="Other">Other</option>
#                 </select>
#             </div>
#
#             <div class="input-group">
#                 <input type="date" name="dob" placeholder="Date of Birth">
#             </div>
#
#             <div class="input-group">
#                 <input type="text" name="nationality" placeholder="Nationality">
#             </div>
#
#             <div class="input-group">
#                 <input type="text" name="address" placeholder="Address">
#             </div>
#
#             <button type="submit" class="signup-btn">Sign Up</button>
#         </form>
#
#         <p class="login-text">
#             Already have an account? <a href="{% url 'login_page' %}">Login</a>
#         </p>
#     </div>
# </div>
# {% endblock %}

# %% [markdown]
# {% load static %}
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>{% block title %}AirEats{% endblock %}</title>
#     <link rel="stylesheet" href="{% static 'core/style.css' %}">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
# </head>
# <body class="{% block body_class %}{% endblock %}">
#
#     <!-- Header with Logo + Smart Navbar -->
#     <header class="ae-header">
#         <div class="ae-header-inner">
#             <a class="ae-logo" href="{% url 'home' %}">
#                 <img src="{% static 'core/images/logo.png' %}" alt="AirEats Logo" height="48">
#             </a>
#
#             <nav class="ae-nav" aria-label="Main navigation">
#                 <a href="{% url 'home' %}">Home</a>
#
#                 {% if username %}
#                     <a href="{% url 'booking_page' username=username %}">Dashboard</a>
#                     <a href="{% url 'orders_page' username=username %}">Orders</a>
#                     <a href="{% url 'order_history_page' username=username %}">Order History</a>
#                 {% else %}
#                     <a href="{% url 'login_page' %}">Dashboard</a>
#                     <a href="{% url 'login_page' %}">Orders</a>
#                     <a href="{% url 'login_page' %}">Order History</a>
#                 {% endif %}
#
#                 {% if username %}
#                     <span class="ae-nav-username">Hi, {{ username }}</span>
#                 {% else %}
#                     <a class="ae-cta" href="{% url 'login_page' %}">Login</a>
#                     <a class="ae-cta ae-cta-outline" href="{% url 'signup_page' %}">Signup</a>
#                 {% endif %}
#             </nav>
#         </div>
#     </header>
#
#     <!-- Page content -->
#     <main>
#         {% block content %}{% endblock %}
#     </main>
# </body>
# </html>

# %%
<span class="ae-nav-username">Hi, {{ username }}</span>

# %%
{% extends 'core/base.html' %}
{% load static %}

{% block title %}{{ restaurant.name }} - AirEats{% endblock %}

{% block content %}
<h2>{{ restaurant.name }}</h2>

<ul>
  {% for item in restaurant.menu %}
    <li>
      {{ item.dish_name }} - ₹{{ item.price }}
      {% if item.veg %}
        <span style="color:green;">(Veg)</span>
      {% else %}
        <span style="color:red;">(Non-Veg)</span>
      {% endif %}

      <form method="post" action="{% url 'booking_page' username=username %}" style="display:inline;">
        {% csrf_token %}
        <input type="hidden" name="action" value="add">
        <input type="hidden" name="dish_id" value="{{ item.dish_id }}">
        <button type="submit">Add</button>
      </form>
    </li>
  {% endfor %}
</ul>

<a href="{% url 'booking_page' username=username %}">Go to Booking</a>
{% endblock %}

# %%
{% extends 'core/base.html' %}
{% block title %}Payment - AirEats{% endblock %}
{% block content %}

<h2>Payment for Booking {{ booking.booking_id }}</h2>
<p><strong>Total Amount:</strong> ₹{{ booking.amount }}</p>

{% if error %}<p style="color:red;">{{ error }}</p>{% endif %}

<form method="post">
  {% csrf_token %}
  <label>Select Payment Method:</label><br>
  <input type="radio" name="payment_method" value="UPI"> UPI<br>
  <input type="radio" name="payment_method" value="Card"> Card<br>
  <input type="radio" name="payment_method" value="Net Banking"> Net Banking<br>
  <input type="radio" name="payment_method" value="Cash"> Cash<br>
  <br>
  <button type="submit">Make Payment</button>
</form>

{% endblock %}

# %%
{% extends 'core/base.html' %}
{% load custom_filters %}
{% block title %}My Orders - AirEats{% endblock %}
{% block content %}

<h2>Confirmed Orders for {{ username }}</h2>

{% if orders %}
  <ul>
    {% for order in orders %}
      <li>
        <h4>Booking ID: {{ order.booking_id }}</h4>
        <p>Status: {{ order.status }}</p>
        <p>Location: {{ order.location }}</p>
        <p>Total: ₹{{ order.amount }}</p>

        <h5>Items:</h5>
        <ul>
          {% for oi in order.order %}
            <li>{{ oi.dish_name }} — ₹{{ oi.dish_price }} × {{ oi.quantity }}</li>
          {% endfor %}
        </ul>

        {% with payments|get_item:order.booking_id as payment %}
          {% if payment %}
            <h5>Payment Details:</h5>
            <p><strong>Transaction ID:</strong> {{ payment.transaction_id }}</p>
            <p><strong>Method:</strong> {{ payment.payment_method }}</p>
            <p><strong>Timestamp:</strong> {{ payment.timestamp }}</p>
          {% else %}
            <p style="color:red;">⚠ No payment record found!</p>
          {% endif %}
        {% endwith %}

        <form method="post" style="margin-top:10px;">
          {% csrf_token %}
          <input type="hidden" name="booking_id" value="{{ order.booking_id }}">
          <button type="submit">Received</button>
        </form>
      </li>
      <hr>
    {% endfor %}
  </ul>
{% else %}
  <p>No confirmed orders yet.</p>
{% endif %}

{% endblock %}

# %%
{% extends 'core/base.html' %}
{% block title %}Order History - AirEats{% endblock %}
{% block content %}

<h2>Order History for {{ username }}</h2>

{% if orders %}
  <ul>
    {% for order in orders %}
      <li>
        <h4>Booking ID: {{ order.booking_id }}</h4>
        <p>Status: {{ order.status }}</p>
        <p>Location: {{ order.location }}</p>
        <p>Total: ₹{{ order.amount }}</p>

        <h5>Items:</h5>
        <ul>
          {% for oi in order.order %}
            <li>{{ oi.dish_name }} — ₹{{ oi.dish_price }} × {{ oi.quantity }}</li>
          {% endfor %}
        </ul>
      </li>
      <hr>
    {% endfor %}
  </ul>
{% else %}
  <p>No completed orders yet.</p>
{% endif %}

{% endblock %}

# %%
def order_history_page(request, username):
    completed_orders = Booking.objects(username=username, status="Completed").order_by('-date_time')
    return render(request, "core/orderhistory.html", {
        "username": username,
        "orders": completed_orders
    })
